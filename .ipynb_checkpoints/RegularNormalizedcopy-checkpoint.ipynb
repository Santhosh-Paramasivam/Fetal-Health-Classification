# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from performance_measures import performance_measures
import timeit

# %%
from sklearn.linear_model import LogisticRegression # Logistic Regression
from sklearn.svm import SVC # Support Vector Machines
from sklearn.neighbors import KNeighborsClassifier # K-Nearest Neighnors
from sklearn.naive_bayes import GaussianNB # Naive Bayes 
from sklearn.tree import DecisionTreeClassifier # Decision Tree
from sklearn.ensemble import RandomForestClassifier # Random Forest  
from sklearn.ensemble import AdaBoostClassifier # Ada Boost
from sklearn.ensemble import GradientBoostingClassifier # Gradient Boost
from xgboost import XGBClassifier #

# %%
FetalHealth = pd.read_csv(r"source\fetal_health.csv")

# %%
FetalHealth.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %%
FetalHealth.describe().T
# Out:
#                                                      count        mean  \
# baseline value                                      2126.0  133.303857
# accelerations                                       2126.0    0.003178
# fetal_movement                                      2126.0    0.009481
# uterine_contractions                                2126.0    0.004366
# light_decelerations                                 2126.0    0.001889
# severe_decelerations                                2126.0    0.000003
# prolongued_decelerations                            2126.0    0.000159
# abnormal_short_term_variability                     2126.0   46.990122
# mean_value_of_short_term_variability                2126.0    1.332785
# percentage_of_time_with_abnormal_long_term_vari...  2126.0    9.846660
# mean_value_of_long_term_variability                 2126.0    8.187629
# histogram_width                                     2126.0   70.445908
# histogram_min                                       2126.0   93.579492
# histogram_max                                       2126.0  164.025400
# histogram_number_of_peaks                           2126.0    4.068203
# histogram_number_of_zeroes                          2126.0    0.323612
# histogram_mode                                      2126.0  137.452023
# histogram_mean                                      2126.0  134.610536
# histogram_median                                    2126.0  138.090310
# histogram_variance                                  2126.0   18.808090
# histogram_tendency                                  2126.0    0.320320
# fetal_health                                        2126.0    1.304327
#
#                                                           std    min      25%  \
# baseline value                                       9.840844  106.0  126.000
# accelerations                                        0.003866    0.0    0.000
# fetal_movement                                       0.046666    0.0    0.000
# uterine_contractions                                 0.002946    0.0    0.002
# light_decelerations                                  0.002960    0.0    0.000
# severe_decelerations                                 0.000057    0.0    0.000
# prolongued_decelerations                             0.000590    0.0    0.000
# abnormal_short_term_variability                     17.192814   12.0   32.000
# mean_value_of_short_term_variability                 0.883241    0.2    0.700
# percentage_of_time_with_abnormal_long_term_vari...  18.396880    0.0    0.000
# mean_value_of_long_term_variability                  5.628247    0.0    4.600
# histogram_width                                     38.955693    3.0   37.000
# histogram_min                                       29.560212   50.0   67.000
# histogram_max                                       17.944183  122.0  152.000
# histogram_number_of_peaks                            2.949386    0.0    2.000
# histogram_number_of_zeroes                           0.706059    0.0    0.000
# histogram_mode                                      16.381289   60.0  129.000
# histogram_mean                                      15.593596   73.0  125.000
# histogram_median                                    14.466589   77.0  129.000
# histogram_variance                                  28.977636    0.0    2.000
# histogram_tendency                                   0.610829   -1.0    0.000
# fetal_health                                         0.614377    1.0    1.000
#
#                                                         50%      75%      max
# baseline value                                      133.000  140.000  160.000
# accelerations                                         0.002    0.006    0.019
# fetal_movement                                        0.000    0.003    0.481
# uterine_contractions                                  0.004    0.007    0.015
# light_decelerations                                   0.000    0.003    0.015
# severe_decelerations                                  0.000    0.000    0.001
# prolongued_decelerations                              0.000    0.000    0.005
# abnormal_short_term_variability                      49.000   61.000   87.000
# mean_value_of_short_term_variability                  1.200    1.700    7.000
# percentage_of_time_with_abnormal_long_term_vari...    0.000   11.000   91.000
# mean_value_of_long_term_variability                   7.400   10.800   50.700
# histogram_width                                      67.500  100.000  180.000
# histogram_min                                        93.000  120.000  159.000
# histogram_max                                       162.000  174.000  238.000
# histogram_number_of_peaks                             3.000    6.000   18.000
# histogram_number_of_zeroes                            0.000    0.000   10.000
# histogram_mode                                      139.000  148.000  187.000
# histogram_mean                                      136.000  145.000  182.000
# histogram_median                                    139.000  148.000  186.000
# histogram_variance                                    7.000   24.000  269.000
# histogram_tendency                                    0.000    1.000    1.000
# fetal_health                                          1.000    1.000    3.000

# %%
FetalHealth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
#  8   mean_value_of_short_term_variability                    2126 non-null   float64
#  9   percentage_of_time_with_abnormal_long_term_variability  2126 non-null   float64
#  10  mean_value_of_long_term_variability                     2126 non-null   float64
#  11  histogram_width                                         2126 non-null   float64
#  12  histogram_min                                           2126 non-null   float64
#  13  histogram_max                                           2126 non-null   float64
#  14  histogram_number_of_peaks                               2126 non-null   float64
#  15  histogram_number_of_zeroes                              2126 non-null   float64
#  16  histogram_mode                                          2126 non-null   float64
#  17  histogram_mean                                          2126 non-null   float64
#  18  histogram_median                                        2126 non-null   float64
#  19  histogram_variance                                      2126 non-null   float64
#  20  histogram_tendency                                      2126 non-null   float64
#  21  fetal_health                                            2126 non-null   float64
# dtypes: float64(22)
# memory usage: 365.5 KB

# %% [markdown]
# Classes :
# 1. Normal
# 2. Suspect
# 3. Pathological

# %% [markdown]
# Analysis consists of :
#
# 1. Count plot
# 2. Correlation heat map

# %%
colours = ["pink","orange", "red"]
sns.countplot(data = FetalHealth, x = "fetal_health", palette = colours)
# Out:
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\1380002937.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = FetalHealth, x = "fetal_health", palette = colours)
# <Axes: xlabel='fetal_health', ylabel='count'>

# %%
corrmat= FetalHealth.corr()
plt.figure(figsize=(20,20))  

cmap = sns.diverging_palette(250, 10, s=80, l=55, n=9, as_cmap=True)

sns.heatmap(corrmat,annot=True, cmap=cmap, center=0)
# Out:
# <Axes: >

# %%
cols = FetalHealth.columns
for i in cols:
    sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
    plt.show()
# Out:
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3375445255.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=FetalHealth["fetal_health"], y=FetalHealth[i], palette=colours)

# %%
shades =["#f7b2b0","#c98ea6","#8f7198","#50587f", "#003f5c"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = FetalHealth,palette = shades)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\489257876.py:3: UserWarning:
# The palette list has fewer values (5) than needed (22) and will cycle, which may produce an uninterpretable plot.
#   sns.boxenplot(data = FetalHealth,palette = shades)

# %% [markdown]
# Data Preprocessing :
#
# 1. Scaling
# 2. X,y and test, train division

# %%
X = FetalHealth.drop(['fetal_health'], axis = 1)
y = FetalHealth['fetal_health']

# %%
col_names = list(X.columns)
# Three different scaling methods

#s_scaler = preprocessing.StandardScaler()
#s_scaler = preprocessing.MinMaxScaler()
#s_scaler = preprocessing.RobustScaler()
s_scaler = preprocessing.MaxAbsScaler()
#s_scaler = preprocessing.Normalizer()
#s_scaler = preprocessing.QuantileTransformer()

scaler_name = "Max Abs Scaler"
noscale = False
if(noscale):
    X_df = X
else:
    X_df= s_scaler.fit_transform(X)

X_df = pd.DataFrame(X_df, columns=col_names)   
X_df.describe().T
# Out:
#                                                      count      mean  \
# baseline value                                      2126.0  0.833149
# accelerations                                       2126.0  0.167277
# fetal_movement                                      2126.0  0.019710
# uterine_contractions                                2126.0  0.291094
# light_decelerations                                 2126.0  0.125964
# severe_decelerations                                2126.0  0.003293
# prolongued_decelerations                            2126.0  0.031703
# abnormal_short_term_variability                     2126.0  0.540116
# mean_value_of_short_term_variability                2126.0  0.190398
# percentage_of_time_with_abnormal_long_term_vari...  2126.0  0.108205
# mean_value_of_long_term_variability                 2126.0  0.161492
# histogram_width                                     2126.0  0.391366
# histogram_min                                       2126.0  0.588550
# histogram_max                                       2126.0  0.689182
# histogram_number_of_peaks                           2126.0  0.226011
# histogram_number_of_zeroes                          2126.0  0.032361
# histogram_mode                                      2126.0  0.735038
# histogram_mean                                      2126.0  0.739618
# histogram_median                                    2126.0  0.742421
# histogram_variance                                  2126.0  0.069919
# histogram_tendency                                  2126.0  0.320320
#
#                                                          std       min  \
# baseline value                                      0.061505  0.662500
# accelerations                                       0.203452  0.000000
# fetal_movement                                      0.097018  0.000000
# uterine_contractions                                0.196405  0.000000
# light_decelerations                                 0.197347  0.000000
# severe_decelerations                                0.057300  0.000000
# prolongued_decelerations                            0.117990  0.000000
# abnormal_short_term_variability                     0.197619  0.137931
# mean_value_of_short_term_variability                0.126177  0.028571
# percentage_of_time_with_abnormal_long_term_vari...  0.202164  0.000000
# mean_value_of_long_term_variability                 0.111011  0.000000
# histogram_width                                     0.216421  0.016667
# histogram_min                                       0.185913  0.314465
# histogram_max                                       0.075396  0.512605
# histogram_number_of_peaks                           0.163855  0.000000
# histogram_number_of_zeroes                          0.070606  0.000000
# histogram_mode                                      0.087600  0.320856
# histogram_mean                                      0.085679  0.401099
# histogram_median                                    0.077777  0.413978
# histogram_variance                                  0.107724  0.000000
# histogram_tendency                                  0.610829 -1.000000
#
#                                                          25%       50%  \
# baseline value                                      0.787500  0.831250
# accelerations                                       0.000000  0.105263
# fetal_movement                                      0.000000  0.000000
# uterine_contractions                                0.133333  0.266667
# light_decelerations                                 0.000000  0.000000
# severe_decelerations                                0.000000  0.000000
# prolongued_decelerations                            0.000000  0.000000
# abnormal_short_term_variability                     0.367816  0.563218
# mean_value_of_short_term_variability                0.100000  0.171429
# percentage_of_time_with_abnormal_long_term_vari...  0.000000  0.000000
# mean_value_of_long_term_variability                 0.090730  0.145957
# histogram_width                                     0.205556  0.375000
# histogram_min                                       0.421384  0.584906
# histogram_max                                       0.638655  0.680672
# histogram_number_of_peaks                           0.111111  0.166667
# histogram_number_of_zeroes                          0.000000  0.000000
# histogram_mode                                      0.689840  0.743316
# histogram_mean                                      0.686813  0.747253
# histogram_median                                    0.693548  0.747312
# histogram_variance                                  0.007435  0.026022
# histogram_tendency                                  0.000000  0.000000
#
#                                                          75%  max
# baseline value                                      0.875000  1.0
# accelerations                                       0.315789  1.0
# fetal_movement                                      0.006237  1.0
# uterine_contractions                                0.466667  1.0
# light_decelerations                                 0.200000  1.0
# severe_decelerations                                0.000000  1.0
# prolongued_decelerations                            0.000000  1.0
# abnormal_short_term_variability                     0.701149  1.0
# mean_value_of_short_term_variability                0.242857  1.0
# percentage_of_time_with_abnormal_long_term_vari...  0.120879  1.0
# mean_value_of_long_term_variability                 0.213018  1.0
# histogram_width                                     0.555556  1.0
# histogram_min                                       0.754717  1.0
# histogram_max                                       0.731092  1.0
# histogram_number_of_peaks                           0.333333  1.0
# histogram_number_of_zeroes                          0.000000  1.0
# histogram_mode                                      0.791444  1.0
# histogram_mean                                      0.796703  1.0
# histogram_median                                    0.795699  1.0
# histogram_variance                                  0.089219  1.0
# histogram_tendency                                  1.000000  1.0

# %%
#looking at the scaled features
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_df,palette = shades)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_16980\3870634562.py:3: UserWarning:
# The palette list has fewer values (5) than needed (21) and will cycle, which may produce an uninterpretable plot.
#   sns.boxenplot(data = X_df,palette = shades)

# %%
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.3,random_state=42)

# %%
performanceMeasuresDF = pd.DataFrame(columns=['Classifier Model', 'Accuracy','F1-Score','Recall','Precision','Jaccard-Score','Kappa-Score'])

# %%
lr = LogisticRegression(max_iter = 100000)
result = %timeit -o lr.fit(X=X_train, y=y_train) 
lr.fit(X = X_train, y = y_train)
print("Logistic Regression : ")
measures = performance_measures("Logistic Regression", lr, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
#performanceMeasuresDF = pd.concat((performanceMeasuresDF, pd.DataFrame(measures)))
exec_time = result.average
# Out:
# The slowest run took 6.70 times longer than the fastest. This could mean that an intermediate result is being cached.
# 380 ms ± 326 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Logistic Regression :
# Accuracy : 0.9028213166144201
# F1 : 0.8982998458701373
# Recall : 0.9028213166144201
# Precision : 0.8979853360421234
# Jaccard : 0.8271730637143141
# Kappa : 0.7154879127676561

# %%
svmlinear = SVC(kernel = 'linear')
result = %timeit -o svmlinear.fit(X=X_train, y = y_train)
svmlinear.fit(X=X_train, y = y_train)
print("SVM Linear : ")
measures = performance_measures("Support Vector Machine(Linear)", svmlinear, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# 133 ms ± 14.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# SVM Linear :
# Accuracy : 0.8996865203761756
# F1 : 0.8977582535565323
# Recall : 0.8996865203761756
# Precision : 0.8966927661890569
# Jaccard : 0.8250580031687744
# Kappa : 0.7167709446055242

# %%
svmrbf = SVC(kernel = 'rbf')
result = %timeit -o svmrbf.fit(X=X_train, y = y_train)
svmrbf.fit(X=X_train, y = y_train)
print("SVM RBF : ")
measures = performance_measures("Support Vector Machine(RBF)", svmrbf, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# 243 ms ± 71.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# SVM RBF :
# Accuracy : 0.9043887147335423
# F1 : 0.9006073186397274
# Recall : 0.9043887147335423
# Precision : 0.90069325472042
# Jaccard : 0.8297035149490983
# Kappa : 0.7202679585411784

# %% [markdown]
# Two variants which haven't been tried before

# %%
svmpoly = SVC(kernel = 'poly')
result = %timeit -o svmpoly.fit(X=X_train, y = y_train)
svmpoly.fit(X=X_train, y = y_train)
print("SVM Poly : ")
measures = performance_measures("Support Vector Machine(Poly)",svmpoly, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# The slowest run took 4.05 times longer than the fastest. This could mean that an intermediate result is being cached.
# 199 ms ± 114 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# SVM Poly :
# Accuracy : 0.9106583072100314
# F1 : 0.909593361916041
# Recall : 0.9106583072100314
# Precision : 0.9091148998784467
# Jaccard : 0.8432403139166017
# Kappa : 0.7503809563032824

# %%
svmsigmoid = SVC(kernel = 'sigmoid')
result = %timeit -o svmsigmoid.fit(X=X_train, y = y_train)
svmsigmoid.fit(X=X_train, y = y_train)
print("SVM Sigmoid : ")
measures = performance_measures("Support Vector Machine(Sigmoid)",svmsigmoid, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# 281 ms ± 49.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# SVM Sigmoid :
# Accuracy : 0.7115987460815048
# F1 : 0.6693386655523754
# Recall : 0.7115987460815048
# Precision : 0.6510054481272054
# Jaccard : 0.5700189638447507
# Kappa : 0.015299959736948088

# %%
knn = KNeighborsClassifier(n_neighbors=5)
result = %timeit -o knn.fit(X=X_train, y = y_train) 
knn.fit(X=X_train, y = y_train)
print("K-Nearest Neighbors : ")
measures = performance_measures("K-Nearest Neighbors",knn, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# 11.6 ms ± 4.4 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# K-Nearest Neighbors :
# Accuracy : 0.8981191222570533
# F1 : 0.8963282884459647
# Recall : 0.8981191222570533
# Precision : 0.8951918668764792
# Jaccard : 0.823811892217518
# Kappa : 0.7142679969132399

# %%
gnb = GaussianNB()
result = %timeit -o gnb.fit(X_train, y_train)
gnb.fit(X_train, y_train)
print("Naive Bayes : ")
measures = performance_measures("Naive Bayes",gnb, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# 12.5 ms ± 2.32 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Naive Bayes :
# Accuracy : 0.7366771159874608
# F1 : 0.7654981914695341
# Recall : 0.7366771159874608
# Precision : 0.8659593790153199
# Jaccard : 0.6317648747607439
# Kappa : 0.48057436116132213

# %%
dt = DecisionTreeClassifier()
result = %timeit -o dt.fit(X_train, y_train)
dt.fit(X_train, y_train)
print("Decision Trees : ")
measures = performance_measures("Decision Tree",dt, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# 64.5 ms ± 17.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Decision Trees :
# Accuracy : 0.9357366771159875
# F1 : 0.9354583231159741
# Recall : 0.9357366771159875
# Precision : 0.9355384631957685
# Jaccard : 0.8829879236150383
# Kappa : 0.8248965766537695

# %%
rfc = RandomForestClassifier(n_estimators = 100, random_state = 42)
result = %timeit -o rfc.fit(X_train, y_train)
rfc.fit(X_train, y_train)
print("Random Forest Classifier : ")
measures = performance_measures("Random Forest",rfc, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# 1.89 s ± 673 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Random Forest Classifier :
# Accuracy : 0.9435736677115988
# F1 : 0.9419146677509735
# Recall : 0.9435736677115988
# Precision : 0.9425674738802717
# Jaccard : 0.8944142646143795
# Kappa : 0.840207046251461

# %%
abc = AdaBoostClassifier(n_estimators = 100, random_state = 42)
result = %timeit -o abc.fit(X_train, y_train)
abc.fit(X_train, y_train)
print("Ada Boost Classifier : ")
measures = performance_measures("Ada Boost",abc, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# c:\Users\Santhosh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Santhosh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Santhosh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Santhosh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Santhosh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Santhosh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Santhosh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Santhosh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# 1.73 s ± 308 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# c:\Users\Santhosh\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Ada Boost Classifier :
# Accuracy : 0.896551724137931
# F1 : 0.8969976888268296
# Recall : 0.896551724137931
# Precision : 0.8975154836089501
# Jaccard : 0.8213382338099839
# Kappa : 0.7190477461368064

# %%
gbc = GradientBoostingClassifier(n_estimators = 100, random_state = 42, learning_rate = 1.0, max_depth = 1)
result = %timeit -o gbc.fit(X_train, y_train)
gbc.fit(X_train, y_train)
print("Gradient Boost Classifier : ")
measures = performance_measures("Gradient Boost",gbc, X_test, y_test, performanceMeasuresDF)
performanceMeasuresDF.loc[len(performanceMeasuresDF)] = measures
exec_time += result.average
# Out:
# 2.55 s ± 350 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Gradient Boost Classifier :
# Accuracy : 0.9028213166144201
# F1 : 0.9022129472115995
# Recall : 0.9028213166144201
# Precision : 0.9032924190667232
# Jaccard : 0.8318844617069766
# Kappa : 0.7323970341505655

# %%
performanceMeasuresDF
# Out:
#                    Classifier Model  Accuracy  F1-Score    Recall  Precision  \
# 0               Logistic Regression  0.902821  0.898300  0.902821   0.897985
# 1    Support Vector Machine(Linear)  0.899687  0.897758  0.899687   0.896693
# 2       Support Vector Machine(RBF)  0.904389  0.900607  0.904389   0.900693
# 3      Support Vector Machine(Poly)  0.910658  0.909593  0.910658   0.909115
# 4   Support Vector Machine(Sigmoid)  0.711599  0.669339  0.711599   0.651005
# 5               K-Nearest Neighbors  0.898119  0.896328  0.898119   0.895192
# 6                       Naive Bayes  0.736677  0.765498  0.736677   0.865959
# 7                     Decision Tree  0.935737  0.935458  0.935737   0.935538
# 8                     Random Forest  0.943574  0.941915  0.943574   0.942567
# 9                         Ada Boost  0.896552  0.896998  0.896552   0.897515
# 10                   Gradient Boost  0.902821  0.902213  0.902821   0.903292
#
#     Jaccard-Score  Kappa-Score
# 0        0.827173     0.715488
# 1        0.825058     0.716771
# 2        0.829704     0.720268
# 3        0.843240     0.750381
# 4        0.570019     0.015300
# 5        0.823812     0.714268
# 6        0.631765     0.480574
# 7        0.882988     0.824897
# 8        0.894414     0.840207
# 9        0.821338     0.719048
# 10       0.831884     0.732397

# %%
performanceMeasuresDF["Weighted_Score"] = performanceMeasuresDF["Accuracy"] + performanceMeasuresDF["F1-Score"] + performanceMeasuresDF["Recall"] + performanceMeasuresDF["Precision"] + performanceMeasuresDF["Jaccard-Score"] + performanceMeasuresDF["Kappa-Score"]

# %%
performanceTable = performanceMeasuresDF.sort_values(by = "Weighted_Score",ascending= False)

# %%
performanceTable.to_excel("results\\"+ scaler_name + '.xlsx', index = False)

# %%
print(exec_time)

with open(r"results/" + scaler_name + r" Timings.txt", "+a") as file:
    file.write(str(exec_time) + "\n")
# Out:
# 7.490542459421724

# %%
import winsound
freq = 1000
dur = 2000
winsound.Beep(freq,dur)
winsound.Beep(freq + 100,dur)

# %%
#%reset
